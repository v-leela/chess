# %% [markdown]
# # Error Analysis

# %% [markdown]
# the biggest problem with all the models are they are really bad at predicting the "Draw"s, so feature engineering more "Draw" focused features would be better.

# %%
import os
import pandas as pd
import numpy as np

# %%
project_dir = os.path.dirname(os.getcwd())

# %% [markdown]
# #### loading the data
